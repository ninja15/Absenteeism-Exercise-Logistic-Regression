# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('Absenteeism_predictions.csv')
df.head()
# Out:
#    Reason_1  Reason_2  Reason_3  Reason_4  Month Value  \
# 0         0       0.0         0         1            6
# 1         1       0.0         0         0            6
# 2         0       0.0         0         1            6
# 3         0       0.0         0         1            6
# 4         1       0.0         0         0            6
#
#    Transportation Expense  Age  Body Mass Index  Education  Children  Pet  \
# 0                     179   30               19          1         0    0
# 1                     361   28               27          0         1    4
# 2                     155   34               25          0         2    0
# 3                     179   40               22          1         2    0
# 4                     155   34               25          0         2    0
#
#    Probability  Prediction
# 0     0.122799           0
# 1     0.873392           1
# 2     0.268305           0
# 3     0.196385           0
# 4     0.723502           1

# %%
plt.figure(figsize=(10,6))
plt.scatter(x='Age', y='Probability', data=df)
plt.xlabel('Age')
plt.ylabel('Probability')
# Out:
# Text(0, 0.5, 'Probability')

# %%
sns.pairplot(df)
